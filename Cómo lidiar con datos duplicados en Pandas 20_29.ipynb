# %%
import pandas as pd

# %%
df = pd.DataFrame({'a': ['w'] * 4 + ['x'] * 3 + ['y'] * 2 + ['z']+['v'], 
                   'b': [1, 1, 1, 1, 2, 2, 2, 3, 3, 4,5]})
df
# Out:
#     a  b
# 0   w  1
# 1   w  1
# 2   w  1
# 3   w  1
# 4   x  2
# 5   x  2
# 6   x  2
# 7   y  3
# 8   y  3
# 9   z  4
# 10  v  5

# %%
df.duplicated() #marca con True aquellos casos de filas duplicadas
# Out:
# 0     False
# 1      True
# 2      True
# 3      True
# 4     False
# 5      True
# 6      True
# 7     False
# 8      True
# 9     False
# 10    False
# dtype: bool

# %%
df.duplicated(keep='first') # marca solo la primera ocurrencia
# Out:
# 0     False
# 1      True
# 2      True
# 3      True
# 4     False
# 5      True
# 6      True
# 7     False
# 8      True
# 9     False
# 10    False
# dtype: bool

# %%
df.duplicated(keep='last') # marca solo la última ocurrencia
# Out:
# 0      True
# 1      True
# 2      True
# 3     False
# 4      True
# 5      True
# 6     False
# 7      True
# 8     False
# 9     False
# 10    False
# dtype: bool

# %%
df[~ df.duplicated()]  # Filtra aquellos casos que no tienen duplicados, el ~ es negación
# Out:
#     a  b
# 0   w  1
# 4   x  2
# 7   y  3
# 9   z  4
# 10  v  5

# %%
df.duplicated(keep=False) # Marca todos los registros duplicados
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
# 5      True
# 6      True
# 7      True
# 8      True
# 9     False
# 10    False
# dtype: bool

# %%
df[df.duplicated(keep=False)]
# Out:
#    a  b
# 0  w  1
# 1  w  1
# 2  w  1
# 3  w  1
# 4  x  2
# 5  x  2
# 6  x  2
# 7  y  3
# 8  y  3

# %%
df.drop_duplicates() # descarta los registros duplicados, tiene por defecto el keep = first
# Out:
#     a  b
# 0   w  1
# 4   x  2
# 7   y  3
# 9   z  4
# 10  v  5

# %%
df.drop_duplicates(['a'],keep='last') # elimina los duplicados teniendo en cuenta una sola columna
# Out:
#     a  b
# 3   w  1
# 6   x  2
# 8   y  3
# 9   z  4
# 10  v  5
