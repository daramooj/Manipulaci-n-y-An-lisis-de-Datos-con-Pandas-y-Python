# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd '/content/drive/MyDrive/Colab Notebooks/db'
# !ls
# Out:
# /content/drive/MyDrive/Colab Notebooks/db
# conexion_bd.ipynb  Copia_de_superstore_1.xls  test.csv	test.xls

# %%
import pandas as pd
import numpy as np

# %%
exa_excel = pd.read_excel('Copia_de_superstore_1.xls')

# %%
exa_excel
# Out:
#       Row ID        Order ID Order Date  ... Quantity Discount    Profit
# 0          1  CA-2016-152156 2016-11-08  ...        2     0.00   41.9136
# 1          2  CA-2016-152156 2016-11-08  ...        3     0.00  219.5820
# 2          3  CA-2016-138688 2016-06-12  ...        2     0.00    6.8714
# 3          4  US-2015-108966 2015-10-11  ...        5     0.45 -383.0310
# 4          5  US-2015-108966 2015-10-11  ...        2     0.20    2.5164
# ...      ...             ...        ...  ...      ...      ...       ...
# 9989    9990  CA-2014-110422 2014-01-21  ...        3     0.20    4.1028
# 9990    9991  CA-2017-121258 2017-02-26  ...        2     0.00   15.6332
# 9991    9992  CA-2017-121258 2017-02-26  ...        2     0.20   19.3932
# 9992    9993  CA-2017-121258 2017-02-26  ...        4     0.00   13.3200
# 9993    9994  CA-2017-119914 2017-05-04  ...        2     0.00   72.9480
#
# [9994 rows x 21 columns]

# %%
# %cd '/content/drive/MyDrive/Colab Notebooks/'
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %%
exa_excel
# Out:
#       Row ID        Order ID Order Date  ... Quantity Discount    Profit
# 0          1  CA-2016-152156 2016-11-08  ...        2     0.00   41.9136
# 1          2  CA-2016-152156 2016-11-08  ...        3     0.00  219.5820
# 2          3  CA-2016-138688 2016-06-12  ...        2     0.00    6.8714
# 3          4  US-2015-108966 2015-10-11  ...        5     0.45 -383.0310
# 4          5  US-2015-108966 2015-10-11  ...        2     0.20    2.5164
# ...      ...             ...        ...  ...      ...      ...       ...
# 9989    9990  CA-2014-110422 2014-01-21  ...        3     0.20    4.1028
# 9990    9991  CA-2017-121258 2017-02-26  ...        2     0.00   15.6332
# 9991    9992  CA-2017-121258 2017-02-26  ...        2     0.20   19.3932
# 9992    9993  CA-2017-121258 2017-02-26  ...        4     0.00   13.3200
# 9993    9994  CA-2017-119914 2017-05-04  ...        2     0.00   72.9480
#
# [9994 rows x 21 columns]

# %%
# !ls
# Out:
# 'Curso de Manipulación y Análisis de Datos con Pandas y Python Curso de Manipulación y Análisis de Datos con Pandas y Python'
#  db
# 'ejemplo de leer un excel.ipynb'
#  introduccion_colab-2_b57bfddc-9484-4701-a638-64bcb1061ae6.ipynb
# 'introduccion_colab_live_07b0ed82-599e-45a5-a89a-cbcdb23943bb (1).ipynb'
#  introduccion_colab_live_07b0ed82-599e-45a5-a89a-cbcdb23943bb.ipynb
#  Untitled0.ipynb
#  Untitled1.ipynb

# %%
df = pd.DataFrame(exa_excel)
